# %%
# @title Compressão de arquivos .csv para .parquet

import pandas as pd

old_dataset_path = "?"
new_dataset_path = "?"

df = pd.read_csv(old_dataset_path)
df.to_parquet(new_dataset_path, engine="pyarrow", compression="zstd")

# df = pd.read_parquet(dataset_path)
